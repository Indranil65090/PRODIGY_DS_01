# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("World_Population.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   #                        234 non-null    int64
#  1   Country (or dependency)  234 non-null    object
#  2   Population (2023)        234 non-null    int64
#  3   Yearly Change            234 non-null    object
#  4   Net Change               234 non-null    int64
#  5   Density  (P/Km²)         234 non-null    int64
#  6   Land Area  (Km²)         234 non-null    int64
#  7   Migrants (net)           234 non-null    int64
#  8   Fert. Rate               234 non-null    object
#  9   Med. Age                 233 non-null    float64
#  10  Urban Pop %              234 non-null    object
#  11  World Share              234 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 22.1+ KB

# %%
df.describe()
# Out:
#                 #  Population (2023)    Net Change  Density  (P/Km²)  \
# count  234.000000       2.340000e+02  2.340000e+02        234.000000
# mean   117.500000       3.437565e+07  3.000230e+05        477.414530
# std     67.694165       1.373861e+08  1.001815e+06       2320.693692
# min      1.000000       5.180000e+02 -2.957105e+06          0.000000
# 25%     59.250000       4.696482e+05  2.360000e+02         38.250000
# 50%    117.500000       5.643895e+06  2.860150e+04         96.500000
# 75%    175.750000       2.324537e+07  2.236855e+05        242.000000
# max    234.000000       1.428628e+09  1.145449e+07      24360.000000
#
#        Land Area  (Km²)  Migrants (net)    Med. Age
# count      2.340000e+02    2.340000e+02  233.000000
# mean       5.559568e+05    1.301282e+01   31.309013
# std        1.691024e+06    1.698334e+05    9.628386
# min        0.000000e+00   -9.104750e+05   15.000000
# 25%        2.650000e+03   -9.776750e+03   22.000000
# ...

# %%
df.head(8)
# Out:
#    # Country (or dependency)  Population (2023) Yearly Change  Net Change  \
# 0  1                   India         1428627663        0.81 %    11454490
# 1  2                   China         1425671352       -0.02 %     -215985
# 2  3           United States          339996563         0.5 %     1706706
# 3  4               Indonesia          277534122        0.74 %     2032783
# 4  5                Pakistan          240485658        1.98 %     4660796
# 5  6                 Nigeria          223804632        2.41 %     5263420
# 6  7                  Brazil          216422446        0.52 %     1108948
# 7  8              Bangladesh          172954319        1.03 %     1767947
#
#    Density  (P/Km²)  Land Area  (Km²)  Migrants (net) Fert. Rate  Med. Age  \
# 0               481           2973190         -486136      1.999      28.0
# 1               152           9388211         -310220       1.19      39.0
# 2                37           9147420          999700      1.662      38.0
# ...

# %%
df.tail(8)
# Out:
#        #  Country (or dependency)  Population (2023) Yearly Change  \
# 226  227         Saint Barthelemy              10994        0.25 %
# 227  228  Saint Pierre & Miquelon               5840       -0.38 %
# 228  229             Saint Helena               5314       -1.12 %
# 229  230               Montserrat               4386       -0.09 %
# 230  231         Falkland Islands               3791        0.29 %
# 231  232                     Niue               1935        0.05 %
# 232  233                  Tokelau               1893        1.18 %
# 233  234                 Holy See                518        1.57 %
#
#      Net Change  Density  (P/Km²)  Land Area  (Km²)  Migrants (net)  \
# 226          27               524                21               0
# 227         -22                25               230               0
# 228         -60                14               390               0
# 229          -4                44               100               0
# ...

# %%
df.columns
# Out:
# Index(['#', 'Country (or dependency)', 'Population (2023)', 'Yearly Change',
#        'Net Change', 'Density  (P/Km²)', 'Land Area  (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
df.dtypes
# Out:
# #                            int64
# Country (or dependency)     object
# Population (2023)            int64
# Yearly Change               object
# Net Change                   int64
# Density  (P/Km²)             int64
# Land Area  (Km²)             int64
# Migrants (net)               int64
# Fert. Rate                  object
# Med. Age                   float64
# Urban Pop %                 object
# World Share                 object
# dtype: object

# %%
df.shape
# Out:
# (234, 12)

# %%
df.sort_values(ascending=True,by='Population (2023)')
# Out:
#        # Country (or dependency)  Population (2023) Yearly Change  Net Change  \
# 233  234                Holy See                518        1.57 %           8
# 232  233                 Tokelau               1893        1.18 %          22
# 231  232                    Niue               1935        0.05 %           1
# 230  231        Falkland Islands               3791        0.29 %          11
# 229  230              Montserrat               4386       -0.09 %          -4
# ..   ...                     ...                ...           ...         ...
# 4      5                Pakistan          240485658        1.98 %     4660796
# 3      4               Indonesia          277534122        0.74 %     2032783
# 2      3           United States          339996563         0.5 %     1706706
# 1      2                   China         1425671352       -0.02 %     -215985
# 0      1                   India         1428627663        0.81 %    11454490
#
# ...

# %%
df.corr()
# Out:
#                           #  Population (2023)  Net Change  Density  (P/Km²)  \
# #                  1.000000          -0.359631   -0.398096          0.122935
# Population (2023) -0.359631           1.000000    0.621103         -0.025359
# Net Change        -0.398096           0.621103    1.000000         -0.032072
# Density  (P/Km²)   0.122935          -0.025359   -0.032072          1.000000
# Land Area  (Km²)  -0.392013           0.451759    0.170999         -0.059129
# Migrants (net)    -0.006037          -0.169378   -0.301581         -0.003888
# Med. Age           0.260929          -0.009930   -0.284370          0.200981
#
#                    Land Area  (Km²)  Migrants (net)  Med. Age
# #                         -0.392013       -0.006037  0.260929
# Population (2023)          0.451759       -0.169378 -0.009930
# Net Change                 0.170999       -0.301581 -0.284370
# Density  (P/Km²)          -0.059129       -0.003888  0.200981
# ...

# %%
sns.barplot(x='Med. Age',y='Fert. Rate',data=df.head(10))
plt.title('Fertility Rate by Median Age of top 10 Countries')
plt.show()

# %%
sns.histplot(df['Med. Age'],kde=True)
plt.title('Median Age')
plt.show()
